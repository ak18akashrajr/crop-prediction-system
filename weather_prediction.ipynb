# %%
import pandas as pd
df=pd.read_csv("weatherHistory.csv")
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
my_list = list(df)
my_list
# Out:
# ['Formatted Date',
#  'Summary',
#  'Precip Type',
#  'Temperature (C)',
#  'Apparent Temperature (C)',
#  'Humidity',
#  'Wind Speed (km/h)',
#  'Wind Bearing (degrees)',
#  'Visibility (km)',
#  'Loud Cover',
#  'Pressure (millibars)',
#  'Daily Summary']

# %%
check_nan = df['Precip Type'].isnull().sum()
check_nan
# Out:
# 517

# %%
df.rename(columns = {'Formatted Date':'date', 'Summary':'summary',
                              'Precip Type':'type'}, inplace = True)
df
# Out:
#                                 date        summary  type  Temperature (C)  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy  rain         9.472222
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy  rain         9.355556
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy  rain         9.377778
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy  rain         8.288889
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy  rain         8.755556
# ...                              ...            ...   ...              ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy  rain        26.016667
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy  rain        24.583333
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy  rain        22.038889
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy  rain        21.522222
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy  rain        20.438889
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
df=df.drop(['date', 'summary','Wind Bearing (degrees)','Loud Cover','Daily Summary','type'], axis=1)
df
# Out:
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# 1             9.355556                  7.227778      0.86            14.2646
# 2             9.377778                  9.377778      0.89             3.9284
# 3             8.288889                  5.944444      0.83            14.1036
# 4             8.755556                  6.977778      0.83            11.0446
# ...                ...                       ...       ...                ...
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
# ...

# %%
df.rename(columns = {'Temperature (C)':'temp', 'Apparent Temperature (C)':'app_temp',
                              'Wind Speed (km/h)':'w_speed','Humidity':'humidity','Visibility (km)':'visibility',
                              'Pressure (millibars)':'pressure'}, inplace = True)
df
# Out:
#             temp   app_temp  humidity  w_speed  visibility  pressure
# 0       9.472222   7.388889      0.89  14.1197     15.8263   1015.13
# 1       9.355556   7.227778      0.86  14.2646     15.8263   1015.63
# 2       9.377778   9.377778      0.89   3.9284     14.9569   1015.94
# 3       8.288889   5.944444      0.83  14.1036     15.8263   1016.41
# 4       8.755556   6.977778      0.83  11.0446     15.8263   1016.51
# ...          ...        ...       ...      ...         ...       ...
# 96448  26.016667  26.016667      0.43  10.9963     16.1000   1014.36
# 96449  24.583333  24.583333      0.48  10.0947     15.5526   1015.16
# 96450  22.038889  22.038889      0.56   8.9838     16.1000   1015.66
# 96451  21.522222  21.522222      0.60  10.5294     16.1000   1015.95
# 96452  20.438889  20.438889      0.61   5.8765     15.5204   1016.16
#
# [96453 rows x 6 columns]

# %%
check_nan = df['visibility'].isnull().sum()
check_nan
# Out:
# 0

# %%
X=df[['temp','app_temp','w_speed','visibility','pressure']]
X
# Out:
#             temp   app_temp  w_speed  visibility  pressure
# 0       9.472222   7.388889  14.1197     15.8263   1015.13
# 1       9.355556   7.227778  14.2646     15.8263   1015.63
# 2       9.377778   9.377778   3.9284     14.9569   1015.94
# 3       8.288889   5.944444  14.1036     15.8263   1016.41
# 4       8.755556   6.977778  11.0446     15.8263   1016.51
# ...          ...        ...      ...         ...       ...
# 96448  26.016667  26.016667  10.9963     16.1000   1014.36
# 96449  24.583333  24.583333  10.0947     15.5526   1015.16
# 96450  22.038889  22.038889   8.9838     16.1000   1015.66
# 96451  21.522222  21.522222  10.5294     16.1000   1015.95
# 96452  20.438889  20.438889   5.8765     15.5204   1016.16
#
# [96453 rows x 5 columns]

# %%
Y=df[['humidity']]
Y
# Out:
#        humidity
# 0          0.89
# 1          0.86
# 2          0.89
# 3          0.83
# 4          0.83
# ...         ...
# 96448      0.43
# 96449      0.48
# 96450      0.56
# 96451      0.60
# 96452      0.61
#
# [96453 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.1,random_state=42)

# %%
from sklearn import linear_model
model=linear_model.LinearRegression()
model.fit(X_train,Y_train)
b=model.score(X_test,Y_test)
b
# Out:
# 0.4776945553749764

# %%
model.predict(X_test)
# Out:
# array([[0.50205333],
#        [0.73217596],
#        [0.7228254 ],
#        ...,
#        [0.50883097],
#        [0.74253337],
#        [0.71272444]])

# %%
from sklearn import linear_model
ridge = linear_model.Ridge(alpha=10)
ridge.fit(X_train,Y_train)
training_ridge = ridge.score(X_test,Y_test)
print("training accuracy with ridge ",training_ridge )
# Out:
# training accuracy with ridge  0.4776941708642126

# %%
import matplotlib.pyplot as plt  
# data to display on plots  
x = ["Ridge Regression","Linear Regression"]  
y = [training_ridge,b]  
  
# This will plot a simple bar chart 
plt.bar(x, y) 
  
# Title to the plot 
plt.title("Bar Chart") 
  
# Adding the legends 
plt.legend(["bar"]) 
plt.show()
